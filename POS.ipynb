# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

csv = pd.read_excel("D:\File_Analisa_Python\POS.xlsx")

csv.fillna(0)

data = csv[['TLBF15','TOT']]
x = data['TLBF15']
y = data['TOT']

plt.scatter(x,y)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.show()
